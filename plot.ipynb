# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('output/u_final.csv', header=None)
plt.imshow(df.values, cmap='viridis', origin='lower')
plt.colorbar()
plt.show()

df = pd.read_csv('output/v_final.csv', header=None)
plt.imshow(df.values, cmap='viridis', origin='lower')
plt.colorbar()
plt.show()
